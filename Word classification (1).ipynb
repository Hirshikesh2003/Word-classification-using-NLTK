# %%
import nltk

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

# %%
file1 = open('''directory of the text file that has the words scrapped from the URL''' ,encoding="utf-8") 
line = file1.read()
words = line.split()

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\aksha\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aksha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemma = WordNetLemmatizer()

# %%
lemmatize = [lemma.lemmatize(w) for w in words]
lemmatize
#print(type(lemmatize))
# Out:
# ['How',
#  'machine',
#  'learning',
#  'affect',
#  'business?',
#  '-',
#  'Blackcoffer',
#  'Insights',
#  'Our',
#  'Success',
#  'Stories',
#  'Banking,',
#  'Financials,',
#  'Securities,',
#  'Insurance',
#  'Energy',
#  'Entertainment',
#  'Fast',
#  'Moving',
#  'Consumer',
#  'Goods',
#  'Government',
#  '&',
#  'Think',
#  'Tanks',
#  'Healthcare',
#  'Infrastructure',
#  '&',
#  'Real',
#  'Estate',
#  'IT',
#  'Lifestyle,',
#  'eCommerce',
#  '&',
#  'Online',
#  'Market',
#  'Place',
#  'Production',
#  '&',
#  'Manufacturing',
#  'Research',
#  '&',
#  'Academia',
#  'Retail',
#  '&',
#  'Supply',
#  'Chain',
#  'Telecom',
#  'What',
#  'We',
#  'Do',
#  'Banking,',
#  'Financials,',
#  'Securities,',
#  'Insurance',
#  'Energy',
#  'Entertainment',
#  'Fast',
#  'Moving',
#  'Consumer',
#  'Goods',
#  'Government',
#  '&',
#  'Think',
#  'Tanks',
#  'Healthcare',
#  'Hospitality',
#  'Infrastructure',
#  '&',
#  'Real',
#  'Estate',
#  'IT',
#  'Services',
# ...

# %%
file = open('''directory from the local computer where you have saved the negative words file''')
neg_words = file.read().split()
file = open('''directory which has the positive words file''')
pos_words = file.read().split()

# %%
pos_num = 0
neg_num = 0
for i in words:
    if i in neg_words:
        neg_num+=1
    if i in pos_words:
        pos_num+=1

# %%
print(neg_num)
print(pos_num)
# Out:
# 10
# 42

# %%
polarity = (pos_num-neg_num)/((pos_num+neg_num)+0.000001)
polarity
# Out:
# 0.6153846035502961

# %%
total_words_after_cleaning = 1168
total_words = 1572

# %%
Sub_Score = (pos_num + neg_num)/ ((total_words_after_cleaning) + 0.000001)
Sub_Score
# Out:
# 0.044520547907088565

# %%
avg_sen_len = (total_words)/(53)
avg_sen_len
# Out:
# 29.660377358490567

# %%
avg_num_of_words_per_sentence = total_words_after_cleaning/63
avg_num_of_words_per_sentence
# Out:
# 18.53968253968254

# %%
word_count = total_words_after_cleaning
word_count
# Out:
# 1168

# %%
words
# Out:
# ['How',
#  'machine',
#  'learning',
#  'affect',
#  'business?',
#  '-',
#  'Blackcoffer',
#  'Insights',
#  'Our',
#  'Success',
#  'Stories',
#  'Banking,',
#  'Financials,',
#  'Securities,',
#  'Insurance',
#  'Energy',
#  'Entertainment',
#  'Fast',
#  'Moving',
#  'Consumer',
#  'Goods',
#  'Government',
#  '&',
#  'Think',
#  'Tanks',
#  'Healthcare',
#  'Infrastructure',
#  '&',
#  'Real',
#  'Estate',
#  'IT',
#  'Lifestyle,',
#  'eCommerce',
#  '&',
#  'Online',
#  'Market',
#  'Place',
#  'Production',
#  '&',
#  'Manufacturing',
#  'Research',
#  '&',
#  'Academia',
#  'Retail',
#  '&',
#  'Supply',
#  'Chain',
#  'Telecom',
#  'What',
#  'We',
#  'Do',
#  'Banking,',
#  'Financials,',
#  'Securities,',
#  'Insurance',
#  'Energy',
#  'Entertainment',
#  'Fast',
#  'Moving',
#  'Consumer',
#  'Goods',
#  'Government',
#  '&',
#  'Think',
#  'Tanks',
#  'Healthcare',
#  'Hospitality',
#  'Infrastructure',
#  '&',
#  'Real',
#  'Estate',
#  'IT',
#  'Services',
# ...
